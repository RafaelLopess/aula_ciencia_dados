# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelLopess/aula_ciencia_dados/blob/main/C%C3%B3pia_de_aula26_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as srn
import statistics as sts
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/enhanced_anxiety_dataset.csv")
df.shape
# Out:
# (11000, 19)

# %%
# grafico por genero

group_gender = df.groupby(['Gender']).size()
group_gender.plot.pie()
# Out:
# <Axes: >

# %%
##Histograma
dados numericos
dados agrupados por intervalos de valores (bins)
distribuição de frequência

# %%
# histograma das horas de sono
# kde = linha de densidade
# densidade = melhora a visualização
# bins = numero de linhas
srn.histplot(df['Sleep Hours'],
            kde = True,
            bins = 15,
            color = 'purple').set_title('Horas de sono')
# Out:
# Text(0.5, 1.0, 'Horas de sono')

# %%
# só a linha de densidade
srn.kdeplot(df['Sleep Hours'])
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Density'>

# %%
#histograma da atividade física (Physical Activity (hrs/week))
srn.histplot(df['Physical Activity (hrs/week)'],
            bins = 10).set_title('Atividade Física')
# Out:
# Text(0.5, 1.0, 'Atividade Física')

# %%
# histograma comparando dois atributos
# engenheiros x horas de sono
srn.histplot(
    df.loc[df['Occupation'] == 'Engineer']['Sleep Hours']
).set_title('Horas de Sono dos Engenheiros')
# Out:
# Text(0.5, 1.0, 'Horas de Sono dos Engenheiros')

# %%
# histograma comparando dois atributos
# engenheiros x horas de sono
srn.histplot(
    df.loc[df['Occupation'] == 'Artist']['Sleep Hours']
).set_title('Horas de Sono dos Engenheiros')
# Out:
# Text(0.5, 1.0, 'Horas de Sono dos Engenheiros')

# %%
## Boxplot
* gráfico/diagrama de caixa ou whisker blot
* distribuição

# %%
df.head()
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# 0                        No                   10               114
# 1                       Yes                    1                62
# 2                       Yes                    1                91
# 3                        No                    4                86
# 4                        No                    1                98
#
#    Breathing Rate (breaths/min)  Sweating Level (1-5) Dizziness Medication  \
# 0                            14                     4        No        Yes
# 1                            23                     2       Yes         No
# 2                            28                     3        No         No
# 3                            17                     3        No         No
# 4                            19                     4       Yes        Yes
#
#    Therapy Sessions (per month) Recent Major Life Event  Diet Quality (1-10)  \
# 0                             3                     Yes                    7
# 1                             2                      No                    8
# 2                             1                     Yes                    1
# 3                             0                      No                    1
# 4                             1                      No                    3
#
#    Anxiety Level (1-10)
# 0                   5.0
# 1                   3.0
# 2                   1.0
# 3                   2.0
# 4                   1.0

# %%
#resumo estatístico
df['Sleep Hours'].describe()
# Out:
# count    11000.000000
# mean         6.650691
# std          1.227509
# min          2.300000
# 25%          5.900000
# 50%          6.700000
# 75%          7.500000
# max         11.300000
# Name: Sleep Hours, dtype: float64

# %%
#boxplot com matplotlib.pyplot
plt.boxplot(df['Sleep Hours'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ca30a7c4490>,
#   <matplotlib.lines.Line2D at 0x7ca30a7c6450>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ca30a7c5a10>,
#   <matplotlib.lines.Line2D at 0x7ca30a7c7810>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ca30b04cf10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ca30a7c5710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ca30a7c4790>],
#  'means': []}

# %%
# boxplot com a biblioteca seaborn
srn.boxplot(df['Sleep Hours'])
# Out:
# <Axes: ylabel='Sleep Hours'>

# %%
##Gráfico de dispersão
*scatter plot
*visualizar como duas variáveis se relacionam

# %%
# Utilizar outra base de dados

df_trees = pd.read_csv('trees.csv')
df_trees.shape
# Out:
# (31, 3)

# %%
df_trees.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
df_trees.tail()
# Out:
#     Girth  Height  Volume
# 26   17.5      82    55.7
# 27   17.9      80    58.3
# 28   18.0      80    51.5
# 29   18.0      80    51.0
# 30   20.6      87    77.0

# %%
# comparar circunferencia X volume

plt.scatter(df_trees['Girth'], df_trees['Volume'])
plt.title('Comparação da circunferência pelo volume das árvores')
#rótulos
plt.xlabel('Circunferência')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
#grafico de linha

plt.plot(df_trees['Girth'], df_trees['Volume'])
plt.title('Comparação da circunferência pelo volume das árvores')
#rótulos
plt.xlabel('Circunferência')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
df.head()
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# 0                        No                   10               114
# 1                       Yes                    1                62
# 2                       Yes                    1                91
# 3                        No                    4                86
# 4                        No                    1                98
#
#    Breathing Rate (breaths/min)  Sweating Level (1-5) Dizziness Medication  \
# 0                            14                     4        No        Yes
# 1                            23                     2       Yes         No
# 2                            28                     3        No         No
# 3                            17                     3        No         No
# 4                            19                     4       Yes        Yes
#
#    Therapy Sessions (per month) Recent Major Life Event  Diet Quality (1-10)  \
# 0                             3                     Yes                    7
# 1                             2                      No                    8
# 2                             1                     Yes                    1
# 3                             0                      No                    1
# 4                             1                      No                    3
#
#    Anxiety Level (1-10)
# 0                   5.0
# 1                   3.0
# 2                   1.0
# 3                   2.0
# 4                   1.0

# %%
#histograma do nivel de ansiedade de médicos

srn.histplot(
    df.loc[df['Occupation'] == 'Doctor']['Anxiety Level (1-10)'],
    bins = 9

).set_title('Nível de ansiedade em médicos')
# Out:
# Text(0.5, 1.0, 'Nível de ansiedade em médicos')

# %%
#histograma do nivel de ansiedade de médicos

srn.histplot(
    df.loc[df['Occupation'] == 'Engineer']['Anxiety Level (1-10)'],
    bins = 9

).set_title('Nível de ansiedade em engenheiros')
# Out:
# Text(0.5, 1.0, 'Nível de ansiedade em engenheiros')

# %%
#histograma do nivel de ansiedade de médicos

srn.histplot(
    df.loc[df['Occupation'] == 'Nurse']['Anxiety Level (1-10)'],
    bins = 9

).set_title('Nível de ansiedade em enfermeiros')
# Out:
# Text(0.5, 1.0, 'Nível de ansiedade em enfermeiros')

# %%
#histograma do nivel de ansiedade de médicos

srn.histplot(
    df.loc[df['Occupation'] == 'Scientist']['Anxiety Level (1-10)'],
    bins = 9

).set_title('Nível de ansiedade em cisntistas')
# Out:
# Text(0.5, 1.0, 'Nível de ansiedade em cisntistas')
